# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
df=pd.read_excel("DATASETCOPPER.xlsx")
df
# Out:
#      S.No  power_rating  weight_of_copper category
# 0       0         16.46             34.69     high
# 1       1         12.52             28.78     high
# 2       2          7.66             21.48      low
# 3       3         21.09             41.64     high
# 4       4         24.43             46.64     high
# ..    ...           ...               ...      ...
# 96     96         46.48             79.73     high
# 97     97         15.95             33.93     high
# 98     98         30.03             55.05     high
# 99     99         15.63             33.45     high
# 100   100         46.91             80.36     high
#
# [101 rows x 4 columns]

# %%
df = df.drop("S.No",axis = 1) 
df.head()
# Out:
#    power_rating  weight_of_copper category
# 0         16.46             34.69     high
# 1         12.52             28.78     high
# 2          7.66             21.48      low
# 3         21.09             41.64     high
# 4         24.43             46.64     high

# %%
df = df.drop("category",axis = 1) 
df.head()
# Out:
#    power_rating  weight_of_copper
# 0         16.46             34.69
# 1         12.52             28.78
# 2          7.66             21.48
# 3         21.09             41.64
# 4         24.43             46.64

# %%
plt.xlabel("POWER RATING")
plt.ylabel("AMOUNT OF COPPER")
plt.title("COPPER PREDICTION IN GENERATOR")
plt.hist(df[['power_rating','weight_of_copper']])
# Out:
# (array([[18., 25., 22., 12., 12., 12.,  0.,  0.,  0.,  0.],
#         [ 0.,  3., 13., 17., 20., 11., 12.,  5.,  7., 13.]]),
#  array([ 5.3  , 13.204, 21.108, 29.012, 36.916, 44.82 , 52.724, 60.628,
#         68.532, 76.436, 84.34 ]),
#  <a list of 2 BarContainer objects>)

# %%
from sklearn.model_selection import train_test_split

x = np.array(df['power_rating'])   
y = df['weight_of_copper']         

x = x.reshape(-1, 1)   

x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.3, random_state=42
)

len(x_train)
# Out:
# 70

# %%
len(y_train)
len(x_test)
len(y_test)
# Out:
# 31

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
